# %% [markdown]
# <a href="https://colab.research.google.com/github/Chethanbhat04/Telecom-Customer-Churn/blob/main/Telecom_Customer_Churn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Clean and Transformation

# %% [markdown]
# **Importing Libraries and Data Set**

# %%
# importing libraries
import pandas as pd
import numpy as np

# Ignore all warnings
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings(action='ignore', category=DeprecationWarning)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# Loading telecom customer churn dataset labeled "telecom_churn"

# %%
df = pd.read_csv("/content/telecom_churn.csv")

# %% [markdown]
# Identifying No. of rows and column

# %%
df.shape
# Out:
# (115, 37)

# %%
df.head(4)
# Out:
#    CustomerID  Gender  Age Married  NumberofDependents          City  ZipCode  \
# 0  0002-ORFBO  Female   37     Yes                   0  Frazier Park    93225
# 1  0003-MKNFE    Male   46      No                   0      Glendale    91206
# 2  0004-TLHLJ    Male   50      No                   0    Costa Mesa    92627
# 3  0011-IGKFF    Male   78     Yes                   0      Martinez    94553
#
#    Population  NumberofReferrals  TenureinMonths    Offer PhoneService  \
# 0        4498                  2               9  Offer A          Yes
# 1       31297                  0               9  Offer B          Yes
# 2       62069                  0               4  Offer C          Yes
# 3       46677                  1              13  Offer E          Yes
#
#    AvgMonthlyLongDistanceCharges MultipleLines InternetService InternetType  \
# 0                          42.39            No             Yes        Cable
# ...

# %% [markdown]
# Review each column to learn it’s datatype and memory usage

# %% [markdown]
# * There are 37 columns with various value counts per column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 37 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CustomerID                     115 non-null    object
#  1   Gender                         115 non-null    object
#  2   Age                            115 non-null    int64
#  3   Married                        115 non-null    object
#  4   NumberofDependents             115 non-null    int64
#  5   City                           115 non-null    object
#  6   ZipCode                        115 non-null    int64
#  7   Population                     115 non-null    int64
#  8   NumberofReferrals              115 non-null    int64
#  9   TenureinMonths                 115 non-null    int64
#  10  Offer                          115 non-null    object
#  11  PhoneService                   115 non-null    object
# ...

# %% [markdown]
# Searching for the columns with ***NaN(null)*** values

# %% [markdown]
# * Some columns have the same number of NaNs which are Phone Service and Internet Service
# * they are related to a specific value within the data frame

# %%
df.isnull().sum()
# Out:
# CustomerID                        0
# Gender                            0
# Age                               0
# Married                           0
# NumberofDependents                0
# City                              0
# ZipCode                           0
# Population                        0
# NumberofReferrals                 0
# TenureinMonths                    0
# Offer                             0
# PhoneService                      0
# AvgMonthlyLongDistanceCharges    12
# MultipleLines                    12
# InternetService                   0
# InternetType                     21
# AvgMonthlyGBDownload             21
# OnlineSecurity                   21
# OnlineBackup                     21
# DeviceProtectionPlan             21
# PremiumTechSupport               21
# StreamingTV                      21
# StreamingMovies                  21
# StreamingMusic                   21
# UnlimitedData                    21
# Contract                          0
# ...

# %% [markdown]
# Pick two columns within each of the Phone Service & Internet Service

# %%
df[df['MultipleLines'].isnull()].head(3)
# Out:
#     CustomerID  Gender  Age Married  NumberofDependents                 City  \
# 10  0017-DINOC    Male   47      No                   0      Rancho Santa Fe
# 14  0019-GFNTW  Female   39      No                   0           Los Olivos
# 16  0020-JDNXP  Female   52     Yes                   1  Point Reyes Station
#
#     ZipCode  Population  NumberofReferrals  TenureinMonths    Offer  \
# 10    92091        1072                  0              54  Offer D
# 14    93441        1317                  0              56  Offer E
# 16    94956        1885                  0              34  Offer A
#
#    PhoneService  AvgMonthlyLongDistanceCharges MultipleLines InternetService  \
# 10           No                            NaN           NaN             Yes
# 14           No                            NaN           NaN             Yes
# 16           No                            NaN           NaN             Yes
#
#    InternetType  AvgMonthlyGBDownload OnlineSecurity OnlineBackup  \
# ...

# %% [markdown]
# * We can see that when ***Internet Service = No*** then the Internet columns have ***NaN***
# * If a customer did not have internet service, their average monthly GB download would not be available.
# * the same is true for Churn Category and Churn Reason also.

# %%
df[df['StreamingMusic'].isnull()].head(3)
# Out:
#     CustomerID  Gender  Age Married  NumberofDependents      City  ZipCode  \
# 20  0023-UYUPN  Female   79     Yes                   0  Ahwahnee    93601
# 23  0030-FNXPP  Female   22      No                   0    Keeler    93530
# 24  0031-PVLZI  Female   34     Yes                   0    Korbel    95550
#
#     Population  NumberofReferrals  TenureinMonths    Offer PhoneService  \
# 20        1968                  0              50  Offer E          Yes
# 23          71                  0               3  Offer B          Yes
# 24         155                  0               4  Offer D          Yes
#
#     AvgMonthlyLongDistanceCharges MultipleLines InternetService InternetType  \
# 20                          31.43           Yes              No          NaN
# 23                           3.12            No              No          NaN
# 24                          12.43            No              No          NaN
#
# ...

# %% [markdown]
# Exclude object data types and describes them

# %%
df.describe(exclude = ['O'])
# Out:
#          Age  NumberofDependents  ZipCode  Population  NumberofReferrals  \
# count 115.00              115.00   115.00      115.00             115.00
# mean   48.08                0.52 93612.03    21221.62               2.14
# std    17.78                1.00  1748.16    21831.05               3.21
# min    19.00                0.00 90001.00       71.00               0.00
# 25%    32.50                0.00 92235.00     2075.00               0.00
# 50%    48.00                0.00 93601.00    12466.00               0.00
# 75%    61.00                0.50 95280.00    34979.50               3.00
# max    80.00                3.00 96140.00    93315.00              10.00
#
#        TenureinMonths  AvgMonthlyLongDistanceCharges  AvgMonthlyGBDownload  \
# count          115.00                         103.00                 94.00
# mean            33.09                          24.87                 25.68
# std             24.25                          15.30                 19.76
# ...

# %% [markdown]
# Include object data types and describes them

# %%
df.describe(include = ['O'])
# Out:
#         CustomerID  Gender Married         City    Offer PhoneService  \
# count          115     115     115          115      115          115
# unique         115       2       2          100        5            2
# top     0002-ORFBO  Female     Yes  Los Angeles  Offer B          Yes
# freq             1      63      60            5       32          103
#
#        MultipleLines InternetService InternetType OnlineSecurity OnlineBackup  \
# count            103             115           94             94           94
# unique             2               2            3              2            2
# top               No             Yes  Fiber Optic             No           No
# freq              52              94           60             54           51
#
#        DeviceProtectionPlan PremiumTechSupport StreamingTV StreamingMovies  \
# count                    94                 94          94              94
# ...

# %% [markdown]
# **CLeaning of Data Set**

# %% [markdown]
# * Replace binary columns with 1 or 0
# * This is because machine learning algorithms and logistic regression analysis requires numbers rather than text (strings)

# %%
df['Churn']=df['Churn'].replace('Joined', 'Stayed')
df['Churn']=df['Churn'].replace(['Stayed','Churned'], [0,1])
df['Married']=df['Married'].replace(['Yes','No'],[1,0])
df['Gender'] = df['Gender'].replace(['Female','Male'],[0,1])
df['PaperlessBilling']=df['PaperlessBilling'].replace(['Yes','No'],[1,0])
df['InternetService']=df['InternetService'].replace(['Yes','No'],[1,0])
df['PhoneService']=df['PhoneService'].replace(['Yes','No'],[1,0])

# %% [markdown]
# * Fill the columns that are NaN and are numerical columns with 0

# %%
df['AvgMonthlyGBDownload'] = df['AvgMonthlyGBDownload'].fillna(0)
df['AvgMonthlyLongDistanceCharges'] = df['AvgMonthlyLongDistanceCharges'].fillna(0)

# %% [markdown]
# * Replace all of the columns that are text and have more than 2 unique values with "Unknown"
# * delete these columns would cause too much data loss and their unknown values could be valuable to the analysis.

# %%
cols_to_change= ['ChurnCategory','ChurnReason', 'UnlimitedData','StreamingMusic',
                  'StreamingMovies','StreamingTV','PremiumTechSupport','DeviceProtectionPlan'
                  ,'OnlineSecurity','OnlineBackup','InternetType','MultipleLines']

df[cols_to_change]=df[cols_to_change].fillna('Unknown')

# %% [markdown]
# * Checking columns for any NaN values. I want to see zeros across all columns.

# %%
df.isnull().sum()
# Out:
# CustomerID                       0
# Gender                           0
# Age                              0
# Married                          0
# NumberofDependents               0
# City                             0
# ZipCode                          0
# Population                       0
# NumberofReferrals                0
# TenureinMonths                   0
# Offer                            0
# PhoneService                     0
# AvgMonthlyLongDistanceCharges    0
# MultipleLines                    0
# InternetService                  0
# InternetType                     0
# AvgMonthlyGBDownload             0
# OnlineSecurity                   0
# OnlineBackup                     0
# DeviceProtectionPlan             0
# PremiumTechSupport               0
# StreamingTV                      0
# StreamingMovies                  0
# StreamingMusic                   0
# UnlimitedData                    0
# Contract                         0
# PaperlessBilling                 0
# ...

# %% [markdown]
# **Data Exploration**

# %%
df['Churn'].value_counts()
# 0 = did not exit
# Out:
# Churn
# 0    87
# 1    28
# Name: count, dtype: int64

# %% [markdown]
# * Remove outliers because they will skew both the machine learning model and logistic regression analysis
# * This is not required but helps trim excess data that can cause issues further down the road.
# * Selected total revenue and population as the columns to remove outliers
# * Total Revenue is related to the other columns and by only looking at this column, it removes those who have anomalies in the other columns
# * Also selected population because if a customer lives in an unusually large city, it also means they have access to other telecom providers, who might have better pricing or service

# %%
#Removing outliers from two columns that encompass the entire data set.
#note: these are positive standard deviations

from scipy import stats
df=df[(np.abs(stats.zscore(df['TotalRevenue'])) < 3)]
df=df[(np.abs(stats.zscore(df['Population'])) < 3)]

# %%
df['CustomerID'].count()
# Out:
# 114

# %% [markdown]
# **Exporting Cleaned Data to a new CSV. This will be used for importing to Machine Learning Model**

# %%
df.to_csv('CleanedDF.csv', index = False)

# %% [markdown]
# # Prediction and Probability

# %% [markdown]
# * Import the Libraries

# %%
# !pip install catboost
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 MB 6.9 MB/s eta 0:00:00
# ...

# %%
import time
import pandas as pd
import itertools
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import joblib #load model
import subprocess
from sklearn import feature_selection
#
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
#
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression,RidgeClassifier,SGDClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.preprocessing import OneHotEncoder , OrdinalEncoder,StandardScaler , MinMaxScaler, MaxAbsScaler
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import VotingClassifier
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier,ExtraTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.feature_selection import RFE
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score, recall_score, confusion_matrix, classification_report,f1_score,accuracy_score
from sklearn.dummy import DummyClassifier
from catboost import CatBoostClassifier
#imblen learn
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as imbpipeline

# Get multiple outputs in the same cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Ignore all warnings
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings(action='ignore', category=DeprecationWarning)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.2f' % x)  # goes to two decimal places

# %% [markdown]
# * Load the Cleaned Data Set

# %%
df = pd.read_csv("CleanedDF.csv")

# %% [markdown]
# * Assign the data frame, labeled df, to X and the target variable of Churn to y

# %%
X = df
y = df['Churn']

# %% [markdown]
# * Assign the test and train split of my data frame and the churn variable
# * As an additional note, stratify is an option used to evenly distribute the target variable amongst y_train and y_test. Then chose to shuffle the data to further increase the odds of randomization and prevent overfitting.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.3,
                                                    random_state=42,
                                                    stratify=y,
                                                    shuffle = True
                                                   )

# %% [markdown]
# * This next step is a manual process that needs to be done.
# * We will be splitting out the features as either numerical, categorical or features to be removed

# %%
remove = ['CustomerID','ZipCode','City', 'ChurnCategory','ChurnReason','Churn']

# numercical columns
num_feats = [
 'Age',
 'NumberofDependents',
 'Population',
 'NumberofReferrals',
 'TenureinMonths',
 'AvgMonthlyLongDistanceCharges',
 'AvgMonthlyGBDownload',
 'MonthlyCharge',
 'TotalCharges',
 'TotalRefunds',
 'TotalExtraDataCharges',
 'TotalLongDistanceCharges',
 'TotalRevenue'
]
# categorical columns
cat_feats = [
 'Gender',
 'Offer',
 'Married',
 'PhoneService',
 'MultipleLines',
 'InternetService',
 'InternetService',
 'InternetType',
 'OnlineSecurity',
 'OnlineBackup',
 'DeviceProtectionPlan',
 'PremiumTechSupport',
 'StreamingTV',
 'StreamingMovies',
 'StreamingMusic',
 'UnlimitedData',
 'Contract',
 'PaperlessBilling',
 'PaymentMethod',
]

# %%
X_test['Churn'].value_counts()
# Out:
# Churn
# 0    26
# 1     9
# Name: count, dtype: int64

# %% [markdown]
# * Now create a copy of X_test and then drop the target value
# * The reason for creating a copy before dropping it, is that we will match the probability of the churn prediction to the customer ID.

# %%
X_testcopy = X_test.copy()
X_testcopy.sample(2)
# Out:
#     CustomerID  Gender  Age  Married  NumberofDependents           City  \
# 76  0123-CRBRT       0   62        1                   0  Monterey Park
# 37  0060-FUALY       0   60        1                   0    Los Angeles
#
#     ZipCode  Population  NumberofReferrals  TenureinMonths    Offer  \
# 76    91755       26933                  1              61  Offer A
# 37    90003       58198                  4              59  Offer B
#
#     PhoneService  AvgMonthlyLongDistanceCharges MultipleLines  \
# 76             1                          47.19           Yes
# 37             1                          16.39           Yes
#
#     InternetService InternetType  AvgMonthlyGBDownload OnlineSecurity  \
# 76                1          DSL                 28.00            Yes
# 37                1  Fiber Optic                 14.00            Yes
#
#    OnlineBackup DeviceProtectionPlan PremiumTechSupport StreamingTV  \
# ...

# %%
print("Columns in X_test:", X_test.columns)
print("Columns in X_train:", X_train.columns)
# Out:
# Columns in X_test: Index(['CustomerID', 'Gender', 'Age', 'Married', 'NumberofDependents', 'City',
#        'ZipCode', 'Population', 'NumberofReferrals', 'TenureinMonths', 'Offer',
#        'PhoneService', 'AvgMonthlyLongDistanceCharges', 'MultipleLines',
#        'InternetService', 'InternetType', 'AvgMonthlyGBDownload',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtectionPlan',
#        'PremiumTechSupport', 'StreamingTV', 'StreamingMovies',
#        'StreamingMusic', 'UnlimitedData', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharge', 'TotalCharges', 'TotalRefunds',
#        'TotalExtraDataCharges', 'TotalLongDistanceCharges', 'TotalRevenue',
#        'Churn', 'ChurnCategory', 'ChurnReason'],
#       dtype='object')
# Columns in X_train: Index(['CustomerID', 'Gender', 'Age', 'Married', 'NumberofDependents', 'City',
#        'ZipCode', 'Population', 'NumberofReferrals', 'TenureinMonths', 'Offer',
# ...

# %%
X_test.drop(remove, axis = 1, inplace = True)
X_train.drop(remove, axis = 1, inplace = True)

# %%
X_testcopy = X_test.copy()
X_testcopy.sample(3)
# Out:
#     Gender  Age  Married  NumberofDependents  Population  NumberofReferrals  \
# 35       0   31        0                   3        5671                  0
# 92       1   41        0                   0        4150                  0
# 74       1   45        0                   0        1851                  0
#
#     TenureinMonths    Offer  PhoneService  AvgMonthlyLongDistanceCharges  \
# 35              43  Offer D             1                          30.64
# 92              25  Offer D             1                          34.88
# 74              50  Offer A             0                           0.00
#
#    MultipleLines  InternetService InternetType  AvgMonthlyGBDownload  \
# 35           Yes                0      Unknown                  0.00
# 92           Yes                1  Fiber Optic                  8.00
# 74       Unknown                1          DSL                  7.00
#
#    OnlineSecurity OnlineBackup DeviceProtectionPlan PremiumTechSupport  \
# ...

# %% [markdown]
# * The next step will be creating a function that acts as pipeline
# * A pipeline allows you to perform a series of data manipulation tasks

# %%
def get_pipeline(X, model):

    numeric_pipeline = SimpleImputer(strategy='mean')
    categorical_pipeline = OneHotEncoder(handle_unknown='ignore')

    preprocessor = ColumnTransformer(
        transformers=[
            ('numeric', numeric_pipeline, num_feats),
            ('categorical', categorical_pipeline, cat_feats),
            ], remainder='passthrough'
    )

    bundled_pipeline = imbpipeline(steps=[
        ('preprocessor', preprocessor),
        ('smote', SMOTE(random_state=42)),
        ('scaler', MinMaxScaler()),
        ('model', model)
    ])

    return bundled_pipeline

# %% [markdown]
# * Select_model function will take X and y datasets and run it through the pipeline
# * The select_model function runs though the various models that has been specified above and then returns the accuracy and run time in a data frame

# %%
def select_model(X, y, pipeline=None):
    classifiers = {}
    classifiers.update({"DummyClassifier": DummyClassifier(strategy='most_frequent')})
    classifiers.update({"XGBClassifier": XGBClassifier(use_label_encoder=False,
                                                       eval_metric='logloss',
                                                       objective='binary:logistic',
                                                      )})
    classifiers.update({"LGBMClassifier": LGBMClassifier()})
    classifiers.update({"RandomForestClassifier": RandomForestClassifier()})
    classifiers.update({"DecisionTreeClassifier": DecisionTreeClassifier()})
    classifiers.update({"ExtraTreeClassifier": ExtraTreeClassifier()})
    #classifiers.update({"ExtraTreesClassifier": ExtraTreeClassifier()})
    classifiers.update({"AdaBoostClassifier": AdaBoostClassifier()})
    classifiers.update({"KNeighborsClassifier": KNeighborsClassifier()})
    classifiers.update({"RidgeClassifier": RidgeClassifier()})
    classifiers.update({"SGDClassifier": SGDClassifier()})
    classifiers.update({"BaggingClassifier": BaggingClassifier()})
    classifiers.update({"BernoulliNB": BernoulliNB()})
    classifiers.update({"SVC": SVC()})
    classifiers.update({"CatBoostClassifier":CatBoostClassifier(silent=True)})

    # Stacking
    models = []

    models = []
    models.append(('XGBClassifier', XGBClassifier(use_label_encoder=False, eval_metric='logloss', objective='binary:logistic')))
    models.append(('CatBoostClassifier', CatBoostClassifier(silent=True)))
    models.append(('BaggingClassifier', BaggingClassifier()))
    classifiers.update({"VotingClassifier (XGBClassifier, CatBoostClassifier, BaggingClassifier)": VotingClassifier(models)})

    models = []
    models.append(('XGBClassifier', XGBClassifier(use_label_encoder=False, eval_metric='logloss', objective='binary:logistic')))
    models.append(('LGBMClassifier', LGBMClassifier()))
    models.append(('CatBoostClassifier', CatBoostClassifier(silent=True)))
    classifiers.update({"VotingClassifier (XGBClassifier, LGBMClassifier, CatBoostClassifier)": VotingClassifier(models)})

    models = []
    models.append(('XGBClassifier', XGBClassifier(use_label_encoder=False, eval_metric='logloss', objective='binary:logistic')))
    models.append(('RandomForestClassifier', RandomForestClassifier()))
    models.append(('DecisionTreeClassifier', DecisionTreeClassifier()))
    classifiers.update({"VotingClassifier (XGBClassifier, RandomForestClassifier, DecisionTreeClassifier)": VotingClassifier(models)})

    models = []
    models.append(('XGBClassifier', XGBClassifier(use_label_encoder=False, eval_metric='logloss', objective='binary:logistic')))
    models.append(('AdaBoostClassifier', AdaBoostClassifier()))
    #models.append(('ExtraTreeClassifier', ExtraTreeClassifier()))
    classifiers.update({"VotingClassifier (XGBClassifier, AdaBoostClassifier)": VotingClassifier(models)})

    models = []
    models.append(('XGBClassifier', XGBClassifier(use_label_encoder=False, eval_metric='logloss', objective='binary:logistic')))
    #models.append(('ExtraTreesClassifier', ExtraTreesClassifier()))
    classifiers.update({"VotingClassifier (XGBClassifier)": VotingClassifier(models)})

    df_models = pd.DataFrame(columns=['model', 'run_time', 'accuracy'])

    for key in classifiers:

        start_time = time.time()

        pipeline = get_pipeline(X_train, classifiers[key])

        cv = cross_val_score(pipeline, X, y, cv=5, scoring='accuracy')

        row = {'model': key,
               'run_time': format(round((time.time() - start_time)/60,2)),
               'accuracy': cv.mean(),
        }

        # Use pd.concat instead of append
        df_models = pd.concat([df_models, pd.DataFrame([row])], ignore_index=True)

    df_models = df_models.sort_values(by='accuracy', ascending=False)
    return df_models

# %%
models = select_model(X_train, y_train)
models.sort_values(by=['accuracy','run_time'], ascending=False)
# Out:
# [LightGBM] [Info] Number of positive: 48, number of negative: 48
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000519 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 496
# [LightGBM] [Info] Number of data points in the train set: 96, number of used features: 43
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# * The voting classifier, which has several algorithms stacked on another, performed the best
# * However, it did take the longest to run
# * Here, the XGBClassifier algorithm is used because it has the highest accuracy and the lowest run time
# * now start to build my initial model before performing any hyperparameter tuning

# %% [markdown]
# Building the Base Model to Test
#
# 1. Build the XGBClassifier
# 2. Use the get_pipeline function to transform my dataset
# 3. Fit the transformed dataset to X_train and y_train
# 4. Take the bundled pipeline dataset and predict using the new X_test dataset to prevent overfitting

# %%
basemodel = XGBClassifier(use_label_encoder = False, eval_metric='logloss', objective='binary:logistic')
bundled_pipeline = get_pipeline(X_train, basemodel)
bundled_pipeline.fit(X_train, y_train)
basemodel_y_pred = bundled_pipeline.predict(X_test)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('numeric', SimpleImputer(),
#                                                   ['Age', 'NumberofDependents',
#                                                    'Population',
#                                                    'NumberofReferrals',
#                                                    'TenureinMonths',
#                                                    'AvgMonthlyLongDistanceCharges',
#                                                    'AvgMonthlyGBDownload',
#                                                    'MonthlyCharge',
#                                                    'TotalCharges',
#                                                    'TotalRefunds',
#                                                    'TotalExtraDataCharges',
# ...

# %%
print(classification_report(y_test, basemodel_y_pred))
print(confusion_matrix(y_test, basemodel_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.93        26
#            1       0.86      0.67      0.75         9
#
#     accuracy                           0.89        35
#    macro avg       0.88      0.81      0.84        35
# weighted avg       0.88      0.89      0.88        35
#
# [[25  1]
#  [ 3  6]]

# %% [markdown]
# **add the models' predictions**

# %%
model = XGBClassifier(
    use_label_encoder = False, eval_metric='logloss', objective='binary:logistic', learning_rate = 0.1,
                     n_estimators = 1000, max_depth = 9, min_child_weight = 1, gamma = 0.4, colsample_bytree = 0.8,
                      subsample = 0.9, reg_alpha = 1, scale_pos_weight = 1)

model = get_pipeline(X_train,model)

model.fit(X_train,y_train)

y_pred = model.predict(X_test)

#predict target probabilities
test_prob = model.predict_proba(X_test)[:,1]

test_pred = np.where(test_prob > 0.45, 1, 0) #sets the probability threshhold and can be tweaked

#test set metrics
roc_auc_score(y_test, test_pred)
recall_score(y_test, test_pred)
confusion_matrix(y_test, test_pred)

print(classification_report(y_test,test_pred))

# adding predictions and their probabilities to the original test Data frame
X_testcopy['predictions'] = test_pred
X_testcopy['pred_probabilities'] = test_prob

high_churn_list = X_testcopy[X_testcopy.pred_probabilities > 0.0].sort_values(by=['pred_probabilities'], ascending = False
                                                                             ).reset_index().drop(columns=['index'],axis=1)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('numeric', SimpleImputer(),
#                                                   ['Age', 'NumberofDependents',
#                                                    'Population',
#                                                    'NumberofReferrals',
#                                                    'TenureinMonths',
#                                                    'AvgMonthlyLongDistanceCharges',
#                                                    'AvgMonthlyGBDownload',
#                                                    'MonthlyCharge',
#                                                    'TotalCharges',
#                                                    'TotalRefunds',
#                                                    'TotalExtraDataCharges',
# ...

# %% [markdown]
# **Export the results:**

# %%
high_churn_list.to_csv('high_churn_list_model.csv', index = False)
